# %% [markdown]
# # Test Strategy
#
# Basic test notebook for template system.

# %%
import pandas as pd
import numpy as np

# Test data
data = pd.DataFrame({
    'price': [100, 102, 101, 103, 105, 104, 106]
})

print(data)
