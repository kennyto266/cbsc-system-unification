# %% [markdown]
# # Risk Management: Position Sizing and Stop Loss
#
# Learn how to implement proper risk management in your trading strategies.

# %%
import pandas as pd
import numpy as np
from cbsc_strategy_sdk import BacktestAdapter

print('Risk Management Tutorial')
