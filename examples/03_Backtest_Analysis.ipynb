# %% [markdown]
# # Backtest Analysis: Deep Dive into Performance Metrics

# %%
from cbsc_strategy_sdk import BacktestAdapter
from datetime import date
import pandas as pd

print('Ready for analysis')
