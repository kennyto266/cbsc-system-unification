# %% [markdown]
# # Parameter Optimization Tutorial
#
# Learn how to optimize strategy parameters using grid search and Bayesian optimization.

# %%
from cbsc_strategy_sdk import ParameterOptimizer
from datetime import date

print('Parameter Optimization Tutorial')
